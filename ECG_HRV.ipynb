# %%
pip install bioread
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load the NeuroKit package
import neurokit2 as nk

# %%
import os
import neurokit2 as nk
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import bioread
# %pylab inline
pylab.rcParams['figure.figsize'] = (14.0, 12.0)
pylab.rcParams['figure.dpi']= 240 
plt.rc('font', size=8)
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
file = bioread.read("C:/Users/Virtuor/Desktop/Neurokit_Biopac_data/SB14/SB14.31.08.23_ortho_Condition.acq")

# %%
ECG_data = file.channels[1].data

# %%
ecg_cleaned_baseline = nk.ecg_clean(ECG_data, sampling_rate=2000)

# %%
peaks, info = nk.ecg_peaks(ECG_data, sampling_rate=2000, correct_artifacts=True)

# %%
"""hrv_indices = nk.hrv(peaks, sampling_rate=2000, show=True)"""
# Out:
# 'hrv_indices = nk.hrv(peaks, sampling_rate=2000, show=True)'

# %%
signals, info = nk.bio_process(ECG_data, sampling_rate=2000)

# %%
hrv_time = nk.hrv_time(peaks, sampling_rate=2000, show=True)
hrv_time
# Out:
#    HRV_MeanNN  HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  803.988131  64.82723   15.731405   63.164146         NaN         NaN
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_IQRNN  HRV_SDRMSSD  \
# 0         NaN         NaN  52.455906  52.534042  ...       88.0     1.235842
#
#    HRV_Prc20NN  HRV_Prc80NN  HRV_pNN50  HRV_pNN20  HRV_MinNN  HRV_MaxNN  \
# 0        745.3        857.4  29.376855  70.326409      667.0     1001.0
#
#      HRV_HTI  HRV_TINN
# 0  12.961538   140.625
#
# [1 rows x 25 columns]

# %%
"""nk.hrv(signals, sampling_rate=2000)"""
# Out:
#    HRV_MeanNN   HRV_SDNN  HRV_SDANN1  HRV_SDNNI1  HRV_SDANN2  HRV_SDNNI2  \
# 0  608.054839  67.622689   30.815941   60.662448   18.807349   65.585975
#
#    HRV_SDANN5  HRV_SDNNI5  HRV_RMSSD   HRV_SDSD  ...  HRV_SampEn  HRV_ShanEn  \
# 0         NaN         NaN  33.781641  33.803483  ...    1.182225    8.340289
#
#    HRV_FuzzyEn  HRV_MSEn  HRV_CMSEn  HRV_RCMSEn    HRV_CD   HRV_HFD  HRV_KFD  \
# 0      0.87059  1.559451   1.370314    2.108756  1.630388  1.600703  2.88831
#
#     HRV_LZC
# 0  0.668768
#
# [1 rows x 91 columns]
